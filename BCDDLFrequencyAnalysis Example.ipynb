# %%
import numpy as np
from BCDDLFrequencyAnalysis import BCDDLFrequencyAnalysis

# %matplotlib inline

# %%
data = np.loadtxt('Stroke2P03I3000D00002.txt')
T = data[:,1]
X = data[:,4]
Y = data[:,3]

# %%
FA = BCDDLFrequencyAnalysis(T,X,Y,ZeroTime=True)
FA.plotData(tmin=0.008,tmax=None)
FA.plotCoherence(4,8,0.008)
FA.plotFRF(128,0.008,fmax=500)
FA.fitLowpass(128,100,0.7,0.0001,0.008,fmax=1000,ffitmax=800)
# Out:
# Optimization terminated successfully.
#          Current function value: 23.522073
#          Iterations: 157
#          Function evaluations: 283
# Fit Parameters:  [4.08575880e+01 7.12513289e-01 1.34393193e-03]
